# %%
# !git clone https://github.com/gaomingqi/sam-body4d.git
# %cd /content/sam-body4d
# Out:
# Cloning into 'sam-body4d'...
# remote: Enumerating objects: 1971, done.
# remote: Counting objects: 100% (286/286), done.
# remote: Compressing objects: 100% (110/110), done.
# remote: Total 1971 (delta 190), reused 208 (delta 176), pack-reused 1685 (from 2)
# Receiving objects: 100% (1971/1971), 137.99 MiB | 16.71 MiB/s, done.
# Resolving deltas: 100% (874/874), done.
# /content/sam-body4d

# %%
# Install detectron2 at the specific commit required
# !pip install 'git+https://github.com/facebookresearch/detectron2.git@a1ce2f9' \
    --no-build-isolation --no-deps -q

# Install SAM3 (bundled inside the repo)
# !pip install -e models/sam3 -q

# Install the main package
# !pip install -e . -q
# Out:
#   WARNING: Did not find branch or tag 'a1ce2f9', assuming revision or ref.
#   Preparing metadata (setup.py) ... done
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for sam3 (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building editable for sam-body4d (pyproject.toml) ... done

# %% [markdown]
# # New Section

# %%
from huggingface_hub import login
login(token="ADD YOUR HF TOKEN")

# %%
# !python scripts/setup.py --ckpt-root /content/checkpoints
# Out:
# [DL]   Config template (release)
# [OK]   Config template (release)
# [OK]   Generated config: /content/sam-body4d/configs/body4d.yaml
# [DL]   Depth Anything v2 (vitl)
# [OK]   Depth Anything v2 (vitl)
# [DL]   Diffusion-VAS amodal segmentation (repo dir)
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:986: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
# ...

# %%
import re

with open("/content/sam-body4d/app.py", "r") as f:
    code = f.read()

code = code.replace(
    'ROOT = os.path.dirname(__file__)',
    'ROOT = "/content/sam-body4d"'
)
code = code.replace(
    'demo.launch()',
    'demo.launch(share=True)'
)

with open("/content/sam-body4d/app.py", "w") as f:
    f.write(code)

print("Done! app.py patched.")

# %%
# %cd /content/sam-body4d
# !python app.py
# Out:
# /content/sam-body4d
# /content/sam-body4d/models/sam_3d_body/sam_3d_body/models/heads/mhr_head.py:33: UserWarning: Momentum is not enabled
#   warnings.warn("Momentum is not enabled")
# /content/sam-body4d/models/sam_3d_body/sam_3d_body/models/heads/mhr_head.py:33: UserWarning: Momentum is not enabled
#   warnings.warn("Momentum is not enabled")
# 2026-04-02 12:35:22.839708: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-02 12:35:22.858727: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
motion retrargeting
